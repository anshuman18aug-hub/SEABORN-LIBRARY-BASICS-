# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot([1,2,3,4,5,6])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot([1,2,3,4,5,6])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.lineplot([1,2,3,4,5,6])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot([1,2,3,4,5,6])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot([1,2,3,4,5,6])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot([1,2,3,4,5,6], kind = "kde")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot([1,2,3,4,5,6], kde = True)
plt.show()
